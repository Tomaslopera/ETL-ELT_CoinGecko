# %% [markdown]
# # ETL CoinGecko

# %%
import os, io, time, json
from datetime import datetime, timezone
from typing import List, Dict, Any

import requests
import pandas as pd
import boto3
from botocore.exceptions import ClientError
from dotenv import load_dotenv

from pathlib import Path
import pyarrow

# %% [markdown]
# ## Extracción
#
# - Consulta a la API pública de CoinGecko para obtener el top 50 de criptomonedas por capitalización

# %%
COINGECKO_URL = (
    "https://api.coingecko.com/api/v3/coins/markets"
    "?vs_currency=usd&order=market_cap_desc&per_page=50&page=1"
    "&price_change_percentage=1h,24h,7d"
)

def extract_from_api(url, timeout):
    resp = requests.get(url, timeout=timeout)
    resp.raise_for_status()
    data = resp.json()
    if not isinstance(data, list) or len(data) == 0:
        raise ValueError("API devolvió estructura inesperada o vacía.")
    return data

raw_records = extract_from_api(COINGECKO_URL, 30)

raw_records
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 114313,
#   'market_cap': 2277021305051,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 2277021305051,
#   'total_volume': 58855014595,
#   'high_24h': 114411,
#   'low_24h': 111599,
#   'price_change_24h': 2255.53,
#   'price_change_percentage_24h': 2.01283,
#   'market_cap_change_24h': 42437202375,
#   'market_cap_change_percentage_24h': 1.89911,
#   'circulating_supply': 19928006.0,
#   'total_supply': 19928006.0,
#   'max_supply': 21000000.0,
#   'ath': 124128,
#   'ath_change_percentage': -7.9074,
#   'ath_date': '2025-08-14T00:37:02.582Z',
#   'atl': 67.81,
#   'atl_change_percentage': 168480.49184,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:22.786Z',
#   'price_change_percentage_1h_in_currency': 0.13487360215119557,
#   'price_change_percentage_24h_in_currency': 2.0128337940805747,
#   'price_change_percentage_7d_in_currency': 1.1985527531567997},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 4225.59,
#   'market_cap': 509726400726,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 509726400726,
#   'total_volume': 35437258130,
#   'high_24h': 4230.02,
#   'low_24h': 4089.64,
#   'price_change_24h': 99.54,
#   'price_change_percentage_24h': 2.41248,
#   'market_cap_change_24h': 11661948372,
#   'market_cap_change_percentage_24h': 2.34145,
#   'circulating_supply': 120703250.5285526,
#   'total_supply': 120703250.5285526,
#   'max_supply': None,
#   'ath': 4946.05,
#   'ath_change_percentage': -14.51318,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 976441.80988,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 48.41284252921999,
#    'currency': 'btc',
#    'percentage': 4841.284252921999},
#   'last_updated': '2025-09-29T23:20:25.315Z',
#   'price_change_percentage_1h_in_currency': 0.05796547055005179,
#   'price_change_percentage_24h_in_currency': 2.4124805245568726,
#   'price_change_percentage_7d_in_currency': 0.7234529845014718},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 174454866853,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 174454866853,
#   'total_volume': 111783934919,
#   'high_24h': 1.001,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0002238,
#   'price_change_percentage_24h': 0.02237,
#   'market_cap_change_24h': 38839249,
#   'market_cap_change_percentage_24h': 0.02227,
#   'circulating_supply': 174372128681.1057,
#   'total_supply': 174372128681.1057,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.38323,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.75026,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.246Z',
#   'price_change_percentage_1h_in_currency': 0.0025638552970510074,
#   'price_change_percentage_24h_in_currency': 0.02237397872132465,
#   'price_change_percentage_7d_in_currency': -0.016331643094815957},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 2.89,
#   'market_cap': 172553781571,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 288382673212,
#   'total_volume': 4905318747,
#   'high_24h': 2.91,
#   'low_24h': 2.85,
#   'price_change_24h': 0.02422369,
#   'price_change_percentage_24h': 0.84649,
#   'market_cap_change_24h': 1333845436,
#   'market_cap_change_percentage_24h': 0.77902,
#   'circulating_supply': 59826504399.0,
#   'total_supply': 99985796373.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -20.85606,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 107333.55424,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:19.767Z',
#   'price_change_percentage_1h_in_currency': -0.16775077334942026,
#   'price_change_percentage_24h_in_currency': 0.8464898860427634,
#   'price_change_percentage_7d_in_currency': 1.1953631976366719},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 1033.05,
#   'market_cap': 143649529111,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 143649529111,
#   'total_volume': 2127461869,
#   'high_24h': 1035.61,
#   'low_24h': 988.9,
#   'price_change_24h': 44.09,
#   'price_change_percentage_24h': 4.45852,
#   'market_cap_change_24h': 6015671305,
#   'market_cap_change_percentage_24h': 4.37078,
#   'circulating_supply': 139185512.06,
#   'total_supply': 139185512.06,
#   'max_supply': 200000000.0,
#   'ath': 1079.07,
#   'ath_change_percentage': -4.07234,
#   'ath_date': '2025-09-21T02:07:58.820Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 2599554.51703,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:22.739Z',
#   'price_change_percentage_1h_in_currency': -0.11022752688672266,
#   'price_change_percentage_24h_in_currency': 4.458524667719113,
#   'price_change_percentage_7d_in_currency': 4.140283923743233},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 213.2,
#   'market_cap': 115992141694,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 130310909683,
#   'total_volume': 6983110189,
#   'high_24h': 214.44,
#   'low_24h': 205.24,
#   'price_change_24h': 3.26,
#   'price_change_percentage_24h': 1.55182,
#   'market_cap_change_24h': 1844734415,
#   'market_cap_change_percentage_24h': 1.6161,
#   'circulating_supply': 543631964.1039314,
#   'total_supply': 610741165.2242442,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -27.1394,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 42573.38958,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:20.136Z',
#   'price_change_percentage_1h_in_currency': -0.16742374259309278,
#   'price_change_percentage_24h_in_currency': 1.5518240686760032,
#   'price_change_percentage_7d_in_currency': -3.40186194779857},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/usdc.png?1696506694',
#   'current_price': 0.999603,
#   'market_cap': 73510517463,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 73524884548,
#   'total_volume': 12022498063,
#   'high_24h': 0.999715,
#   'low_24h': 0.999508,
#   'price_change_24h': -3.9587726770929e-05,
#   'price_change_percentage_24h': -0.00396,
#   'market_cap_change_24h': -157924404.35316467,
#   'market_cap_change_percentage_24h': -0.21437,
#   'circulating_supply': 73532458796.96182,
#   'total_supply': 73546830169.58507,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.75238,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.90735,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.750Z',
#   'price_change_percentage_1h_in_currency': -0.005076738493427983,
#   'price_change_percentage_24h_in_currency': -0.003960187745300076,
#   'price_change_percentage_7d_in_currency': -0.010608270458384377},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://coin-images.coingecko.com/coins/images/13442/large/steth_logo.png?1696513206',
#   'current_price': 4225.43,
#   'market_cap': 36097209192,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 36097209192,
#   'total_volume': 30494952,
#   'high_24h': 4229.7,
#   'low_24h': 4089.09,
#   'price_change_24h': 99.02,
#   'price_change_percentage_24h': 2.39956,
#   'market_cap_change_24h': 842536988,
#   'market_cap_change_percentage_24h': 2.38986,
#   'circulating_supply': 8542654.81741222,
#   'total_supply': 8542654.81741222,
#   'max_supply': None,
#   'ath': 4932.89,
#   'ath_change_percentage': -14.29612,
#   'ath_date': '2025-08-24T19:21:31.902Z',
#   'atl': 482.9,
#   'atl_change_percentage': 775.48446,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.078Z',
#   'price_change_percentage_1h_in_currency': 0.08655905590985154,
#   'price_change_percentage_24h_in_currency': 2.399560646880879,
#   'price_change_percentage_7d_in_currency': 0.828639396106569},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.235571,
#   'market_cap': 35587724527,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 35594702258,
#   'total_volume': 2311021191,
#   'high_24h': 0.238518,
#   'low_24h': 0.229113,
#   'price_change_24h': -0.000763783043638472,
#   'price_change_percentage_24h': -0.32318,
#   'market_cap_change_24h': -124900671.30771637,
#   'market_cap_change_percentage_24h': -0.34974,
#   'circulating_supply': 151118506383.7052,
#   'total_supply': 151148136383.7052,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -67.79964,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 270970.8693,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.365Z',
#   'price_change_percentage_1h_in_currency': -0.40998637702414803,
#   'price_change_percentage_24h_in_currency': -0.3231787450825249,
#   'price_change_percentage_7d_in_currency': -1.8666028435985769},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 0.337196,
#   'market_cap': 31920613545,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 31920683037,
#   'total_volume': 501350374,
#   'high_24h': 0.337473,
#   'low_24h': 0.332641,
#   'price_change_24h': 0.00177446,
#   'price_change_percentage_24h': 0.52902,
#   'market_cap_change_24h': 167582110,
#   'market_cap_change_percentage_24h': 0.52777,
#   'circulating_supply': 94668296204.29051,
#   'total_supply': 94668502301.0101,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -21.76434,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 18600.52123,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 176.47175355279632,
#    'currency': 'usd',
#    'percentage': 17647.175355279633},
#   'last_updated': '2025-09-29T23:20:21.046Z',
#   'price_change_percentage_1h_in_currency': 0.12191358144258019,
#   'price_change_percentage_24h_in_currency': 0.5290234186481141,
#   'price_change_percentage_7d_in_currency': -0.662564688247827},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.80799,
#   'market_cap': 29543818895,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 36393090665,
#   'total_volume': 1328588988,
#   'high_24h': 0.814681,
#   'low_24h': 0.790117,
#   'price_change_24h': -0.00051270016294469,
#   'price_change_percentage_24h': -0.06341,
#   'market_cap_change_24h': -67068626.899196625,
#   'market_cap_change_percentage_24h': -0.2265,
#   'circulating_supply': 36530886109.93794,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -73.78112,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 4103.83395,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:24.545Z',
#   'price_change_percentage_1h_in_currency': -0.2582870312961747,
#   'price_change_percentage_24h_in_currency': -0.06341353357505325,
#   'price_change_percentage_7d_in_currency': -2.277889345496311},
#  {'id': 'wrapped-steth',
#   'symbol': 'wsteth',
#   'name': 'Wrapped stETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/18834/large/wstETH.png?1696518295',
#   'current_price': 5134.03,
#   'market_cap': 16567090754,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 16567090754,
#   'total_volume': 13072929,
#   'high_24h': 5144.51,
#   'low_24h': 4970.7,
#   'price_change_24h': 119.78,
#   'price_change_percentage_24h': 2.38872,
#   'market_cap_change_24h': 395158851,
#   'market_cap_change_percentage_24h': 2.44349,
#   'circulating_supply': 3229512.730552172,
#   'total_supply': 3229512.730552172,
#   'max_supply': None,
#   'ath': 7256.02,
#   'ath_change_percentage': -29.25898,
#   'ath_date': '2022-05-13T15:09:54.509Z',
#   'atl': 558.54,
#   'atl_change_percentage': 818.99994,
#   'atl_date': '2022-05-13T01:36:45.053Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.857Z',
#   'price_change_percentage_1h_in_currency': 0.07830501596133202,
#   'price_change_percentage_24h_in_currency': 2.388715340628001,
#   'price_change_percentage_7d_in_currency': 0.8706301407061442},
#  {'id': 'wrapped-beacon-eth',
#   'symbol': 'wbeth',
#   'name': 'Wrapped Beacon ETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/30061/large/wbeth-icon.png?1696528983',
#   'current_price': 4557.96,
#   'market_cap': 14864344697,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 14864344697,
#   'total_volume': 10050383,
#   'high_24h': 4565.81,
#   'low_24h': 4412.7,
#   'price_change_24h': 103.58,
#   'price_change_percentage_24h': 2.32525,
#   'market_cap_change_24h': 324357287,
#   'market_cap_change_percentage_24h': 2.23079,
#   'circulating_supply': 3264195.799077762,
#   'total_supply': 3264195.799077762,
#   'max_supply': None,
#   'ath': 5330.78,
#   'ath_change_percentage': -14.47983,
#   'ath_date': '2025-08-24T19:27:46.809Z',
#   'atl': 1501.6,
#   'atl_change_percentage': 203.60209,
#   'atl_date': '2025-04-09T03:57:40.245Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.645Z',
#   'price_change_percentage_1h_in_currency': 0.07877887238116242,
#   'price_change_percentage_24h_in_currency': 2.325248404909355,
#   'price_change_percentage_7d_in_currency': 0.8319559771245119},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1696502009',
#   'current_price': 21.8,
#   'market_cap': 14788936722,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 21809375264,
#   'total_volume': 669434088,
#   'high_24h': 21.88,
#   'low_24h': 20.97,
#   'price_change_24h': 0.142163,
#   'price_change_percentage_24h': 0.6564,
#   'market_cap_change_24h': 101604267,
#   'market_cap_change_percentage_24h': 0.69178,
#   'circulating_supply': 678099970.4526168,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -58.52092,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 14650.70387,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:24.643Z',
#   'price_change_percentage_1h_in_currency': -0.09638289983816122,
#   'price_change_percentage_24h_in_currency': 0.656396925234468,
#   'price_change_percentage_7d_in_currency': 1.001781016660578},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1696507857',
#   'current_price': 114353,
#   'market_cap': 14522958849,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 14522958849,
#   'total_volume': 294345445,
#   'high_24h': 114515,
#   'low_24h': 111423,
#   'price_change_24h': 2265.88,
#   'price_change_percentage_24h': 2.02154,
#   'market_cap_change_24h': 270952577,
#   'market_cap_change_percentage_24h': 1.90115,
#   'circulating_supply': 127037.56672278,
#   'total_supply': 127037.56672278,
#   'max_supply': 127037.56672278,
#   'ath': 123882,
#   'ath_change_percentage': -7.66509,
#   'ath_date': '2025-08-14T00:40:53.782Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 3543.82316,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:22.172Z',
#   'price_change_percentage_1h_in_currency': 0.10791402208602202,
#   'price_change_percentage_24h_in_currency': 2.0215425839987624,
#   'price_change_percentage_7d_in_currency': 1.2839606386650806},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 1.001,
#   'market_cap': 14479044264,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 14479044264,
#   'total_volume': 949553555,
#   'high_24h': 1.002,
#   'low_24h': 1.0,
#   'price_change_24h': 0.00024481,
#   'price_change_percentage_24h': 0.02446,
#   'market_cap_change_24h': 158566515,
#   'market_cap_change_percentage_24h': 1.10727,
#   'circulating_supply': 14462399820.40053,
#   'total_supply': 14462399820.40053,
#   'max_supply': None,
#   'ath': 1.032,
#   'ath_change_percentage': -2.9923,
#   'ath_date': '2023-12-20T15:38:34.596Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.71534,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.534Z',
#   'price_change_percentage_1h_in_currency': 0.002676646397564326,
#   'price_change_percentage_24h_in_currency': 0.024458475117051282,
#   'price_change_percentage_7d_in_currency': -0.027246195416841864},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.046,
#   'market_cap': 13317086587,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 13317086587,
#   'total_volume': 56595165,
#   'high_24h': 1.062,
#   'low_24h': 0.980403,
#   'price_change_24h': 0.065775,
#   'price_change_percentage_24h': 6.70893,
#   'market_cap_change_24h': 837263157,
#   'market_cap_change_percentage_24h': 6.70893,
#   'circulating_supply': 12729277815.182,
#   'total_supply': 12729277815.182,
#   'max_supply': None,
#   'ath': 1.062,
#   'ath_change_percentage': -1.48357,
#   'ath_date': '2025-09-29T13:45:20.512Z',
#   'atl': 0.883674,
#   'atl_change_percentage': 18.38957,
#   'atl_date': '2025-09-06T20:28:04.023Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.410Z',
#   'price_change_percentage_1h_in_currency': 0.0,
#   'price_change_percentage_24h_in_currency': 6.708934314875191,
#   'price_change_percentage_7d_in_currency': 4.93215723629567},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 30.42,
#   'market_cap': 12856204253,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 13946207862,
#   'total_volume': 1351191772,
#   'high_24h': 30.78,
#   'low_24h': 29.24,
#   'price_change_24h': 0.534604,
#   'price_change_percentage_24h': 1.78912,
#   'market_cap_change_24h': 242540152,
#   'market_cap_change_percentage_24h': 1.92284,
#   'circulating_supply': 422276596.0335201,
#   'total_supply': 458078999.632708,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -78.95611,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 989.06743,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:23.332Z',
#   'price_change_percentage_1h_in_currency': -0.5221871381171386,
#   'price_change_percentage_24h_in_currency': 1.789123413579294,
#   'price_change_percentage_7d_in_currency': -7.803603862651343},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 46.19,
#   'market_cap': 12529922401,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 46267011951,
#   'total_volume': 616164909,
#   'high_24h': 48.06,
#   'low_24h': 45.14,
#   'price_change_24h': -0.7042621284173336,
#   'price_change_percentage_24h': -1.50171,
#   'market_cap_change_24h': -208161752.6527481,
#   'market_cap_change_percentage_24h': -1.63417,
#   'circulating_supply': 270772999.4341414,
#   'total_supply': 999835210.4341414,
#   'max_supply': 1000000000.0,
#   'ath': 59.3,
#   'ath_change_percentage': -21.56767,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1121.22375,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:15.778Z',
#   'price_change_percentage_1h_in_currency': -0.7138177446115255,
#   'price_change_percentage_24h_in_currency': -1.5017116152336467,
#   'price_change_percentage_7d_in_currency': -3.623608112581586},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.372269,
#   'market_cap': 11908667015,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 18664642762,
#   'total_volume': 216125666,
#   'high_24h': 0.37621,
#   'low_24h': 0.363923,
#   'price_change_24h': 0.0040706,
#   'price_change_percentage_24h': 1.10554,
#   'market_cap_change_24h': 152171029,
#   'market_cap_change_percentage_24h': 1.29436,
#   'circulating_supply': 31902814199.40814,
#   'total_supply': 50001786884.69562,
#   'max_supply': 50001786884.69562,
#   'ath': 0.875563,
#   'ath_change_percentage': -57.48236,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 78087.44101,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:20.405Z',
#   'price_change_percentage_1h_in_currency': -0.12731630613682848,
#   'price_change_percentage_24h_in_currency': 1.1055449927069356,
#   'price_change_percentage_7d_in_currency': 1.2886960633779856},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 3.28,
#   'market_cap': 11715516969,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 32827298589,
#   'total_volume': 730930147,
#   'high_24h': 3.32,
#   'low_24h': 3.21,
#   'price_change_24h': 0.00426344,
#   'price_change_percentage_24h': 0.13002,
#   'market_cap_change_24h': 20395054,
#   'market_cap_change_percentage_24h': 0.17439,
#   'circulating_supply': 3568833706.322776,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -38.44035,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 802.11366,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:20.814Z',
#   'price_change_percentage_1h_in_currency': -0.34700016810353657,
#   'price_change_percentage_24h_in_currency': 0.1300220517979823,
#   'price_change_percentage_7d_in_currency': -2.399945832983889},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 562.05,
#   'market_cap': 11202774921,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 11202774921,
#   'total_volume': 271179544,
#   'high_24h': 563.09,
#   'low_24h': 550.9,
#   'price_change_24h': 4.55,
#   'price_change_percentage_24h': 0.81595,
#   'market_cap_change_24h': 97195163,
#   'market_cap_change_percentage_24h': 0.87519,
#   'circulating_supply': 19932293.64665078,
#   'total_supply': 19932293.64665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -85.16277,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 630.11296,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:23.770Z',
#   'price_change_percentage_1h_in_currency': 0.07047089516425716,
#   'price_change_percentage_24h_in_currency': 0.8159469942429545,
#   'price_change_percentage_7d_in_currency': -0.6497178546833923},
#  {'id': 'wrapped-eeth',
#   'symbol': 'weeth',
#   'name': 'Wrapped eETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/33033/large/weETH.png?1701438396',
#   'current_price': 4552.34,
#   'market_cap': 11134500773,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 11134500773,
#   'total_volume': 23521995,
#   'high_24h': 4561.61,
#   'low_24h': 4404.55,
#   'price_change_24h': 105.92,
#   'price_change_percentage_24h': 2.38211,
#   'market_cap_change_24h': 182213204,
#   'market_cap_change_percentage_24h': 1.6637,
#   'circulating_supply': 2446752.268028754,
#   'total_supply': 2446752.268028754,
#   'max_supply': None,
#   'ath': 5296.78,
#   'ath_change_percentage': -14.07648,
#   'ath_date': '2025-08-24T19:25:19.771Z',
#   'atl': 1505.24,
#   'atl_change_percentage': 202.35676,
#   'atl_date': '2025-04-09T03:45:31.391Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.785Z',
#   'price_change_percentage_1h_in_currency': 0.03561433267529233,
#   'price_change_percentage_24h_in_currency': 2.38211272862817,
#   'price_change_percentage_7d_in_currency': 0.8172593690130757},
#  {'id': 'weth',
#   'symbol': 'weth',
#   'name': 'WETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/2518/large/weth.png?1696503332',
#   'current_price': 4226.11,
#   'market_cap': 10600313903,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 10600313903,
#   'total_volume': 331176505,
#   'high_24h': 4235.18,
#   'low_24h': 4092.09,
#   'price_change_24h': 98.48,
#   'price_change_percentage_24h': 2.3858,
#   'market_cap_change_24h': 174504583,
#   'market_cap_change_percentage_24h': 1.67377,
#   'circulating_supply': 2509895.171233238,
#   'total_supply': 2509895.171233238,
#   'max_supply': None,
#   'ath': 4950.08,
#   'ath_change_percentage': -14.50937,
#   'ath_date': '2025-08-24T19:28:11.411Z',
#   'atl': 82.1,
#   'atl_change_percentage': 5054.29513,
#   'atl_date': '2018-12-15T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:22.308Z',
#   'price_change_percentage_1h_in_currency': 0.04762237612547761,
#   'price_change_percentage_24h_in_currency': 2.38579539778138,
#   'price_change_percentage_7d_in_currency': 0.8335447540544869},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.217017,
#   'market_cap': 9196049638,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 10846207597,
#   'total_volume': 217789755,
#   'high_24h': 0.219417,
#   'low_24h': 0.212449,
#   'price_change_24h': 0.00081487,
#   'price_change_percentage_24h': 0.3769,
#   'market_cap_change_24h': 33724968,
#   'market_cap_change_percentage_24h': 0.36808,
#   'circulating_supply': 42392926541.56971,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -61.78601,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 2105.88839,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:26.358Z',
#   'price_change_percentage_1h_in_currency': -0.4467971875047244,
#   'price_change_percentage_24h_in_currency': 0.3769036646626102,
#   'price_change_percentage_7d_in_currency': -2.0360274394747337},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 9.64,
#   'market_cap': 8889841998,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 9493820253,
#   'total_volume': 642091,
#   'high_24h': 9.66,
#   'low_24h': 9.58,
#   'price_change_24h': 0.04528642,
#   'price_change_percentage_24h': 0.47205,
#   'market_cap_change_24h': 39006761,
#   'market_cap_change_percentage_24h': 0.44071,
#   'circulating_supply': 922560495.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.14,
#   'ath_change_percentage': -4.91239,
#   'ath_date': '2025-03-10T09:26:43.294Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1104.86623,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:16.347Z',
#   'price_change_percentage_1h_in_currency': 0.0321590742774576,
#   'price_change_percentage_24h_in_currency': 0.47205362098647013,
#   'price_change_percentage_7d_in_currency': 1.6340644183541524},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 106.82,
#   'market_cap': 8155185986,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 8155328177,
#   'total_volume': 460950230,
#   'high_24h': 107.28,
#   'low_24h': 105.46,
#   'price_change_24h': -0.10601628355404102,
#   'price_change_percentage_24h': -0.09915,
#   'market_cap_change_24h': -7023804.993285179,
#   'market_cap_change_percentage_24h': -0.08605,
#   'circulating_supply': 76352245.73347135,
#   'total_supply': 76353576.98347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -73.90412,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 9219.02447,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:16.833Z',
#   'price_change_percentage_1h_in_currency': -0.08723139624594121,
#   'price_change_percentage_24h_in_currency': -0.0991485210335224,
#   'price_change_percentage_7d_in_currency': 0.6319638618823202},
#  {'id': 'binance-bridged-usdt-bnb-smart-chain',
#   'symbol': 'bsc-usd',
#   'name': 'Binance Bridged USDT (BNB Smart Chain)',
#   'image': 'https://coin-images.coingecko.com/coins/images/35021/large/USDT.png?1707233575',
#   'current_price': 1.001,
#   'market_cap': 7988456370,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 7988456370,
#   'total_volume': 3048172415,
#   'high_24h': 1.003,
#   'low_24h': 0.997408,
#   'price_change_24h': 0.00021299,
#   'price_change_percentage_24h': 0.02129,
#   'market_cap_change_24h': 3830022,
#   'market_cap_change_percentage_24h': 0.04797,
#   'circulating_supply': 7984993398.453935,
#   'total_supply': 7984993398.453935,
#   'max_supply': None,
#   'ath': 1.05,
#   'ath_change_percentage': -4.69192,
#   'ath_date': '2024-08-05T14:21:42.527Z',
#   'atl': 0.942186,
#   'atl_change_percentage': 6.21022,
#   'atl_date': '2024-12-05T22:30:39.827Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:23.911Z',
#   'price_change_percentage_1h_in_currency': 0.03433240570171196,
#   'price_change_percentage_24h_in_currency': 0.02128670593680401,
#   'price_change_percentage_7d_in_currency': -0.013629543597556469},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999651,
#   'market_cap': 7768219012,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 7768219012,
#   'total_volume': 7751613,
#   'high_24h': 1.001,
#   'low_24h': 0.998066,
#   'price_change_24h': -0.000387984372028027,
#   'price_change_percentage_24h': -0.0388,
#   'market_cap_change_24h': -339399522.96259594,
#   'market_cap_change_percentage_24h': -4.18618,
#   'circulating_supply': 7770385502.36705,
#   'total_supply': 7770385502.36705,
#   'max_supply': None,
#   'ath': 1.057,
#   'ath_change_percentage': -5.45436,
#   'ath_date': '2024-10-29T05:40:51.197Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.41904,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.056Z',
#   'price_change_percentage_1h_in_currency': -0.014925672378049716,
#   'price_change_percentage_24h_in_currency': -0.03879692125624328,
#   'price_change_percentage_7d_in_currency': -0.004224808735783341},
#  {'id': 'usdt0',
#   'symbol': 'usdt0',
#   'name': 'USDT0',
#   'image': 'https://coin-images.coingecko.com/coins/images/53705/large/usdt0.jpg?1737086183',
#   'current_price': 1.0,
#   'market_cap': 7644041871,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 7644041871,
#   'total_volume': 470216018,
#   'high_24h': 1.001,
#   'low_24h': 0.999591,
#   'price_change_24h': 0.00032025,
#   'price_change_percentage_24h': 0.03202,
#   'market_cap_change_24h': 108329016,
#   'market_cap_change_percentage_24h': 1.43754,
#   'circulating_supply': 7640456950.066597,
#   'total_supply': 7640456950.066597,
#   'max_supply': None,
#   'ath': 1.052,
#   'ath_change_percentage': -4.92678,
#   'ath_date': '2025-01-23T22:34:53.341Z',
#   'atl': 0.975737,
#   'atl_change_percentage': 2.50777,
#   'atl_date': '2025-02-28T01:35:58.101Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.885Z',
#   'price_change_percentage_1h_in_currency': 0.020826020272667417,
#   'price_change_percentage_24h_in_currency': 0.032019819964113745,
#   'price_change_percentage_7d_in_currency': 0.010147045952226902},
#  {'id': 'coinbase-wrapped-btc',
#   'symbol': 'cbbtc',
#   'name': 'Coinbase Wrapped BTC',
#   'image': 'https://coin-images.coingecko.com/coins/images/40143/large/cbbtc.webp?1726136727',
#   'current_price': 114254,
#   'market_cap': 7095967070,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 7095967070,
#   'total_volume': 346099538,
#   'high_24h': 114533,
#   'low_24h': 111601,
#   'price_change_24h': 2166.14,
#   'price_change_percentage_24h': 1.93254,
#   'market_cap_change_24h': 114681527,
#   'market_cap_change_percentage_24h': 1.6427,
#   'circulating_supply': 62083.62472294,
#   'total_supply': 62083.62472294,
#   'max_supply': None,
#   'ath': 123939,
#   'ath_change_percentage': -7.8017,
#   'ath_date': '2025-08-14T00:40:22.976Z',
#   'atl': 57439,
#   'atl_change_percentage': 98.94198,
#   'atl_date': '2024-09-12T14:07:41.775Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:24.712Z',
#   'price_change_percentage_1h_in_currency': 0.11867311593880937,
#   'price_change_percentage_24h_in_currency': 1.932536944723201,
#   'price_change_percentage_7d_in_currency': 1.1092819648011139},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 1.2e-05,
#   'market_cap': 7072122234,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 7075183987,
#   'total_volume': 162214337,
#   'high_24h': 1.204e-05,
#   'low_24h': 1.174e-05,
#   'price_change_24h': -1.7985934071e-08,
#   'price_change_percentage_24h': -0.14969,
#   'market_cap_change_24h': -11680233.02265358,
#   'market_cap_change_percentage_24h': -0.16489,
#   'circulating_supply': 589245813587008.5,
#   'total_supply': 589500917367623.5,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -86.06794,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 21295735.49811,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:19.780Z',
#   'price_change_percentage_1h_in_currency': -0.02225889182511022,
#   'price_change_percentage_24h_in_currency': -0.14969154803391418,
#   'price_change_percentage_7d_in_currency': -0.8829363853672079},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 2.7,
#   'market_cap': 6878697953,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 13894790097,
#   'total_volume': 112088747,
#   'high_24h': 2.73,
#   'low_24h': 2.67,
#   'price_change_24h': -0.020116744327491887,
#   'price_change_percentage_24h': -0.73926,
#   'market_cap_change_24h': -50037448.29407787,
#   'market_cap_change_percentage_24h': -0.72217,
#   'circulating_supply': 2545497685.237904,
#   'total_supply': 5141838800.310814,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -67.20853,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 421.11427,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.017Z',
#   'price_change_percentage_1h_in_currency': -0.34726764007181654,
#   'price_change_percentage_24h_in_currency': -0.7392641819043012,
#   'price_change_percentage_7d_in_currency': -3.7887788992587477},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.190692,
#   'market_cap': 6641054658,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 18688181504,
#   'total_volume': 50451993,
#   'high_24h': 0.197286,
#   'low_24h': 0.1876,
#   'price_change_24h': -0.003200495520616409,
#   'price_change_percentage_24h': -1.65066,
#   'market_cap_change_24h': -118063241.42935276,
#   'market_cap_change_percentage_24h': -1.74673,
#   'circulating_supply': 34839379090.82581,
#   'total_supply': 98039343673.93063,
#   'max_supply': 100000000000.0,
#   'ath': 0.965407,
#   'ath_change_percentage': -80.20353,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1476.92128,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:24.753Z',
#   'price_change_percentage_1h_in_currency': -0.43890122695841366,
#   'price_change_percentage_24h_in_currency': -1.6506554572540137,
#   'price_change_percentage_7d_in_currency': -9.1885993330719},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/Mantle-Logo-mark.png?1739213200',
#   'current_price': 1.92,
#   'market_cap': 6247519888,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 11944658347,
#   'total_volume': 357514165,
#   'high_24h': 1.95,
#   'low_24h': 1.73,
#   'price_change_24h': 0.13056,
#   'price_change_percentage_24h': 7.29291,
#   'market_cap_change_24h': 431446725,
#   'market_cap_change_percentage_24h': 7.41818,
#   'circulating_supply': 3252944055.73684,
#   'total_supply': 6219316794.89,
#   'max_supply': 6219316794.89,
#   'ath': 1.95,
#   'ath_change_percentage': -0.89438,
#   'ath_date': '2025-09-29T22:15:05.513Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 526.9234,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:16.845Z',
#   'price_change_percentage_1h_in_currency': -1.0605881813243445,
#   'price_change_percentage_24h_in_currency': 7.292914008589673,
#   'price_change_percentage_7d_in_currency': 11.15090029590709},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 42.1,
#   'market_cap': 6070733570,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 13562774266,
#   'total_volume': 44982526,
#   'high_24h': 42.22,
#   'low_24h': 41.25,
#   'price_change_24h': 0.563302,
#   'price_change_percentage_24h': 1.3563,
#   'market_cap_change_24h': 89374472,
#   'market_cap_change_percentage_24h': 1.49422,
#   'circulating_supply': 144118517.10815412,
#   'total_supply': 321978702.0,
#   'max_supply': 400000000.0,
#   'ath': 52.27,
#   'ath_change_percentage': -19.46591,
#   'ath_date': '2025-06-16T09:30:18.527Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1274.85656,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.467Z',
#   'price_change_percentage_1h_in_currency': 0.05232747319928664,
#   'price_change_percentage_24h_in_currency': 1.3563001313073002,
#   'price_change_percentage_7d_in_currency': -0.43819687321779777},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.png?1696512008',
#   'current_price': 3.99,
#   'market_cap': 6069330766,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 6069330766,
#   'total_volume': 251095391,
#   'high_24h': 4.02,
#   'low_24h': 3.88,
#   'price_change_24h': -0.008550463711739287,
#   'price_change_percentage_24h': -0.21407,
#   'market_cap_change_24h': -22658014.291273117,
#   'market_cap_change_percentage_24h': -0.37193,
#   'circulating_supply': 1522267060.0,
#   'total_supply': 1522267060.0,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -92.72782,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 48.22527,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:18.796Z',
#   'price_change_percentage_1h_in_currency': -0.266781040836314,
#   'price_change_percentage_24h_in_currency': -0.21406580608698622,
#   'price_change_percentage_7d_in_currency': -1.0908531453096164},
#  {'id': 'ethena-staked-usde',
#   'symbol': 'susde',
#   'name': 'Ethena Staked USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33669/large/sUSDe-Symbol-Color.png?1716307680',
#   'current_price': 1.2,
#   'market_cap': 6002166798,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 6002166798,
#   'total_volume': 122635871,
#   'high_24h': 1.2,
#   'low_24h': 1.2,
#   'price_change_24h': 7.644e-05,
#   'price_change_percentage_24h': 0.00638,
#   'market_cap_change_24h': -14513788.080176353,
#   'market_cap_change_percentage_24h': -0.24123,
#   'circulating_supply': 5007090069.456839,
#   'total_supply': 5007090069.456839,
#   'max_supply': None,
#   'ath': 1.29,
#   'ath_change_percentage': -7.14615,
#   'ath_date': '2025-01-29T17:52:32.991Z',
#   'atl': 1.012,
#   'atl_change_percentage': 18.41386,
#   'atl_date': '2024-04-03T14:23:03.162Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.288Z',
#   'price_change_percentage_1h_in_currency': 0.01798724220145098,
#   'price_change_percentage_24h_in_currency': 0.006376780941464985,
#   'price_change_percentage_7d_in_currency': 0.14716926537038488},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.201866,
#   'market_cap': 5496714364,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 20189664524,
#   'total_volume': 443064107,
#   'high_24h': 0.221742,
#   'low_24h': 0.201903,
#   'price_change_24h': -0.018957836223650743,
#   'price_change_percentage_24h': -8.58506,
#   'market_cap_change_24h': -505947865.26039314,
#   'market_cap_change_percentage_24h': -8.42872,
#   'circulating_supply': 27225387313.66336,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -38.86179,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.164016,
#   'atl_change_percentage': 23.50781,
#   'atl_date': '2025-09-04T14:17:54.961Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.861Z',
#   'price_change_percentage_1h_in_currency': -0.9659584944878747,
#   'price_change_percentage_24h_in_currency': -8.58506420365724,
#   'price_change_percentage_7d_in_currency': -4.621732200829134},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 290.72,
#   'market_cap': 5360222839,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 5360222839,
#   'total_volume': 105405765,
#   'high_24h': 293.64,
#   'low_24h': 285.66,
#   'price_change_24h': -1.2295083294968663,
#   'price_change_percentage_24h': -0.42114,
#   'market_cap_change_24h': -17210150.179142952,
#   'market_cap_change_percentage_24h': -0.32004,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -46.12106,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 135066.86759,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:17.296Z',
#   'price_change_percentage_1h_in_currency': -0.32124807181874004,
#   'price_change_percentage_24h_in_currency': -0.421143100771661,
#   'price_change_percentage_7d_in_currency': 0.09658903789311367},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 7.76,
#   'market_cap': 4665197969,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 7769074889,
#   'total_volume': 226275096,
#   'high_24h': 7.83,
#   'low_24h': 7.59,
#   'price_change_24h': 0.00426398,
#   'price_change_percentage_24h': 0.05495,
#   'market_cap_change_24h': 4222895,
#   'market_cap_change_percentage_24h': 0.0906,
#   'circulating_supply': 600483073.71,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -82.68548,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 654.95704,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:21.361Z',
#   'price_change_percentage_1h_in_currency': -0.3398879913200287,
#   'price_change_percentage_24h_in_currency': 0.054949738919406674,
#   'price_change_percentage_7d_in_currency': -5.464820634062316},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999815,
#   'market_cap': 4580655195,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 4580655195,
#   'total_volume': 157414048,
#   'high_24h': 1.001,
#   'low_24h': 0.997448,
#   'price_change_24h': 0.00129944,
#   'price_change_percentage_24h': 0.13014,
#   'market_cap_change_24h': -884455.0204696655,
#   'market_cap_change_percentage_24h': -0.0193,
#   'circulating_supply': 4582016901.278877,
#   'total_supply': 4582016901.278877,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.98131,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.3556,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:24.979Z',
#   'price_change_percentage_1h_in_currency': 0.012233779356263077,
#   'price_change_percentage_24h_in_currency': 0.13013736000900739,
#   'price_change_percentage_7d_in_currency': 0.03021549744516145},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 278.12,
#   'market_cap': 4242706738,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 4451760786,
#   'total_volume': 390692831,
#   'high_24h': 280.18,
#   'low_24h': 269.56,
#   'price_change_24h': 2.8,
#   'price_change_percentage_24h': 1.01851,
#   'market_cap_change_24h': 38329264,
#   'market_cap_change_percentage_24h': 0.91165,
#   'circulating_supply': 15248642.295178635,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -57.974,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 968.59422,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:22.523Z',
#   'price_change_percentage_1h_in_currency': -0.21990438995107253,
#   'price_change_percentage_24h_in_currency': 1.018513837724734,
#   'price_change_percentage_7d_in_currency': 3.3602827876709616},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 191.02,
#   'market_cap': 4009669670,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 4009669670,
#   'total_volume': 69503523,
#   'high_24h': 193.7,
#   'low_24h': 188.86,
#   'price_change_24h': -1.3256109830013258,
#   'price_change_percentage_24h': -0.68919,
#   'market_cap_change_24h': -38495278.85881424,
#   'market_cap_change_percentage_24h': -0.95093,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 255.5,
#   'ath_change_percentage': -25.27872,
#   'ath_date': '2025-08-22T01:50:26.131Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 32781.84522,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:17.836Z',
#   'price_change_percentage_1h_in_currency': 0.2511021421222592,
#   'price_change_percentage_24h_in_currency': -0.6891882239218361,
#   'price_change_percentage_7d_in_currency': 4.059997193483396},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 9.42e-06,
#   'market_cap': 3962419178,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 3962419178,
#   'total_volume': 395893400,
#   'high_24h': 9.49e-06,
#   'low_24h': 9.12e-06,
#   'price_change_24h': -7.1227986e-09,
#   'price_change_percentage_24h': -0.07552,
#   'market_cap_change_24h': -5128809.120186806,
#   'market_cap_change_percentage_24h': -0.12927,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -66.25167,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 17053.85021,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:18.436Z',
#   'price_change_percentage_1h_in_currency': -0.31103442173995965,
#   'price_change_percentage_24h_in_currency': -0.0755227915062269,
#   'price_change_percentage_7d_in_currency': -2.3905724138281825},
#  {'id': 'ethena',
#   'symbol': 'ena',
#   'name': 'Ethena',
#   'image': 'https://coin-images.coingecko.com/coins/images/36530/large/ethena.png?1711701436',
#   'current_price': 0.563782,
#   'market_cap': 3880843286,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 8450010329,
#   'total_volume': 300176660,
#   'high_24h': 0.601874,
#   'low_24h': 0.557938,
#   'price_change_24h': -0.03569336280009361,
#   'price_change_percentage_24h': -5.9541,
#   'market_cap_change_24h': -248134478.4678831,
#   'market_cap_change_percentage_24h': -6.00959,
#   'circulating_supply': 6889062500.0,
#   'total_supply': 15000000000.0,
#   'max_supply': None,
#   'ath': 1.52,
#   'ath_change_percentage': -62.77002,
#   'ath_date': '2024-04-11T13:15:15.057Z',
#   'atl': 0.195078,
#   'atl_change_percentage': 189.64837,
#   'atl_date': '2024-09-06T21:04:48.253Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:25.548Z',
#   'price_change_percentage_1h_in_currency': -0.8692749060865524,
#   'price_change_percentage_24h_in_currency': -5.954104070751197,
#   'price_change_percentage_7d_in_currency': -5.693726931358795},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 5.32,
#   'market_cap': 3720906580,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 4890347667,
#   'total_volume': 289867201,
#   'high_24h': 5.32,
#   'low_24h': 5.17,
#   'price_change_24h': 0.139024,
#   'price_change_percentage_24h': 2.68495,
#   'market_cap_change_24h': 94926704,
#   'market_cap_change_percentage_24h': 2.61796,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 919992035.9787906,
#   'max_supply': 2000000000.0,
#   'ath': 8.45,
#   'ath_change_percentage': -37.0946,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 0.0142795,
#   'atl_change_percentage': 37126.15694,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:23.435Z',
#   'price_change_percentage_1h_in_currency': 0.4021378079412248,
#   'price_change_percentage_24h_in_currency': 2.684949025684003,
#   'price_change_percentage_7d_in_currency': 3.31405980411454},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 2.78,
#   'market_cap': 3478791045,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 3544638449,
#   'total_volume': 214906871,
#   'high_24h': 2.83,
#   'low_24h': 2.7,
#   'price_change_24h': -0.01731595481424586,
#   'price_change_percentage_24h': -0.61834,
#   'market_cap_change_24h': -23156477.537045002,
#   'market_cap_change_percentage_24h': -0.66125,
#   'circulating_supply': 1249836992.0,
#   'total_supply': 1273494211.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -86.34314,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 429.87924,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:17.604Z',
#   'price_change_percentage_1h_in_currency': -0.45006483194232677,
#   'price_change_percentage_24h_in_currency': -0.618338844613235,
#   'price_change_percentage_7d_in_currency': -6.464676256046799},
#  {'id': 'jito-staked-sol',
#   'symbol': 'jitosol',
#   'name': 'Jito Staked SOL',
#   'image': 'https://coin-images.coingecko.com/coins/images/28046/large/JitoSOL-200.png?1696527060',
#   'current_price': 262.75,
#   'market_cap': 3225054972,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 3225054972,
#   'total_volume': 21356379,
#   'high_24h': 264.47,
#   'low_24h': 253.04,
#   'price_change_24h': 3.79,
#   'price_change_percentage_24h': 1.46306,
#   'market_cap_change_24h': 49653059,
#   'market_cap_change_percentage_24h': 1.56368,
#   'circulating_supply': 12270700.81191896,
#   'total_supply': 12270700.81191896,
#   'max_supply': None,
#   'ath': 339.52,
#   'ath_change_percentage': -22.57699,
#   'ath_date': '2025-01-19T11:21:54.080Z',
#   'atl': 0.57898,
#   'atl_change_percentage': 45301.75598,
#   'atl_date': '2023-09-12T10:21:17.665Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:16.017Z',
#   'price_change_percentage_1h_in_currency': -0.12247454051812162,
#   'price_change_percentage_24h_in_currency': 1.463062084955591,
#   'price_change_percentage_7d_in_currency': -3.0813547730657023},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 1.89,
#   'market_cap': 3132696523,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 15118279654,
#   'total_volume': 970811635,
#   'high_24h': 1.99,
#   'low_24h': 1.79,
#   'price_change_24h': -0.01066765985225615,
#   'price_change_percentage_24h': -0.56078,
#   'market_cap_change_24h': -33008000.14665079,
#   'market_cap_change_percentage_24h': -1.04267,
#   'circulating_supply': 1657700000.0,
#   'total_supply': 8000000000.0,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -21.40762,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 1798.52261,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2025-09-29T23:20:23.019Z',
#   'price_change_percentage_1h_in_currency': -0.23760940395458705,
#   'price_change_percentage_24h_in_currency': -0.5607795310506528,
#   'price_change_percentage_7d_in_currency': 17.463890757747382}]

# %% [markdown]
# ## Transform
#
# - Limpieza y normalización de columnas, tipificación y timestamp de corrida

# %%
def transform(records: List[Dict[str, Any]]) -> pd.DataFrame:
    df = pd.DataFrame.from_records(records)
    cols = [
        "id", "symbol", "name",
        "current_price", "market_cap", "total_volume",
        "high_24h", "low_24h",
        "price_change_percentage_1h_in_currency",
        "price_change_percentage_24h_in_currency",
        "price_change_percentage_7d_in_currency",
        "last_updated"
    ]
    keep = [c for c in cols if c in df.columns]
    df = df[keep].copy()
    num_cols = [
        "current_price","market_cap","total_volume","high_24h","low_24h",
        "price_change_percentage_1h_in_currency",
        "price_change_percentage_24h_in_currency",
        "price_change_percentage_7d_in_currency"
    ]
    for c in num_cols:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    if "last_updated" in df.columns:
        df["last_updated"] = pd.to_datetime(df["last_updated"], errors="coerce")
    run_ts = datetime.now(timezone.utc)
    df["run_ts_utc"] = run_ts
    return df

df = transform(raw_records)
df
# Out:
#                                       id      symbol  \
# 0                                bitcoin         btc
# 1                               ethereum         eth
# 2                                 tether        usdt
# 3                                 ripple         xrp
# 4                            binancecoin         bnb
# 5                                 solana         sol
# 6                               usd-coin        usdc
# 7                           staked-ether       steth
# 8                               dogecoin        doge
# 9                                   tron         trx
# 10                               cardano         ada
# 11                         wrapped-steth      wsteth
# 12                    wrapped-beacon-eth       wbeth
# 13                             chainlink        link
# 14                       wrapped-bitcoin        wbtc
# 15                           ethena-usde        usde
# 16                          figure-heloc  figr_heloc
# 17                           avalanche-2        avax
# 18                           hyperliquid        hype
# 19                               stellar         xlm
# 20                                   sui         sui
# 21                          bitcoin-cash         bch
# 22                          wrapped-eeth       weeth
# 23                                  weth        weth
# 24                      hedera-hashgraph        hbar
# 25                             leo-token         leo
# 26                              litecoin         ltc
# 27  binance-bridged-usdt-bnb-smart-chain     bsc-usd
# 28                                  usds        usds
# 29                                 usdt0       usdt0
# 30                  coinbase-wrapped-btc       cbbtc
# 31                             shiba-inu        shib
# 32                      the-open-network         ton
# 33                      crypto-com-chain         cro
# 34                                mantle         mnt
# 35                              whitebit         wbt
# 36                              polkadot         dot
# 37                    ethena-staked-usde       susde
# 38               world-liberty-financial        wlfi
# 39                                monero         xmr
# 40                               uniswap         uni
# 41                                   dai         dai
# 42                                  aave        aave
# 43                                   okb         okb
# 44                                  pepe        pepe
# 45                                ethena         ena
# 46                          bitget-token         bgb
# 47                                  near        near
# 48                       jito-staked-sol     jitosol
# 49                               aster-2       aster
#
#                                       name  current_price     market_cap  \
# 0                                  Bitcoin  114313.000000  2277021305051
# 1                                 Ethereum    4225.590000   509726400726
# 2                                   Tether       1.000000   174454866853
# 3                                      XRP       2.890000   172553781571
# 4                                      BNB    1033.050000   143649529111
# 5                                   Solana     213.200000   115992141694
# 6                                     USDC       0.999603    73510517463
# 7                        Lido Staked Ether    4225.430000    36097209192
# 8                                 Dogecoin       0.235571    35587724527
# 9                                     TRON       0.337196    31920613545
# 10                                 Cardano       0.807990    29543818895
# 11                           Wrapped stETH    5134.030000    16567090754
# 12                      Wrapped Beacon ETH    4557.960000    14864344697
# 13                               Chainlink      21.800000    14788936722
# 14                         Wrapped Bitcoin  114353.000000    14522958849
# 15                             Ethena USDe       1.001000    14479044264
# 16                            Figure Heloc       1.046000    13317086587
# 17                               Avalanche      30.420000    12856204253
# 18                             Hyperliquid      46.190000    12529922401
# 19                                 Stellar       0.372269    11908667015
# 20                                     Sui       3.280000    11715516969
# 21                            Bitcoin Cash     562.050000    11202774921
# 22                            Wrapped eETH    4552.340000    11134500773
# 23                                    WETH    4226.110000    10600313903
# 24                                  Hedera       0.217017     9196049638
# 25                               LEO Token       9.640000     8889841998
# 26                                Litecoin     106.820000     8155185986
# 27  Binance Bridged USDT (BNB Smart Chain)       1.001000     7988456370
# 28                                    USDS       0.999651     7768219012
# 29                                   USDT0       1.000000     7644041871
# 30                    Coinbase Wrapped BTC  114254.000000     7095967070
# 31                               Shiba Inu       0.000012     7072122234
# 32                                 Toncoin       2.700000     6878697953
# 33                                  Cronos       0.190692     6641054658
# 34                                  Mantle       1.920000     6247519888
# 35                           WhiteBIT Coin      42.100000     6070733570
# 36                                Polkadot       3.990000     6069330766
# 37                      Ethena Staked USDe       1.200000     6002166798
# 38                 World Liberty Financial       0.201866     5496714364
# 39                                  Monero     290.720000     5360222839
# 40                                 Uniswap       7.760000     4665197969
# 41                                     Dai       0.999815     4580655195
# 42                                    Aave     278.120000     4242706738
# 43                                     OKB     191.020000     4009669670
# 44                                    Pepe       0.000009     3962419178
# 45                                  Ethena       0.563782     3880843286
# 46                            Bitget Token       5.320000     3720906580
# 47                           NEAR Protocol       2.780000     3478791045
# 48                         Jito Staked SOL     262.750000     3225054972
# 49                                   Aster       1.890000     3132696523
#
#     total_volume       high_24h        low_24h  \
# 0    58855014595  114411.000000  111599.000000
# 1    35437258130    4230.020000    4089.640000
# 2   111783934919       1.001000       1.000000
# 3     4905318747       2.910000       2.850000
# 4     2127461869    1035.610000     988.900000
# 5     6983110189     214.440000     205.240000
# 6    12022498063       0.999715       0.999508
# 7       30494952    4229.700000    4089.090000
# 8     2311021191       0.238518       0.229113
# 9      501350374       0.337473       0.332641
# 10    1328588988       0.814681       0.790117
# 11      13072929    5144.510000    4970.700000
# 12      10050383    4565.810000    4412.700000
# 13     669434088      21.880000      20.970000
# 14     294345445  114515.000000  111423.000000
# 15     949553555       1.002000       1.000000
# 16      56595165       1.062000       0.980403
# 17    1351191772      30.780000      29.240000
# 18     616164909      48.060000      45.140000
# 19     216125666       0.376210       0.363923
# 20     730930147       3.320000       3.210000
# 21     271179544     563.090000     550.900000
# 22      23521995    4561.610000    4404.550000
# 23     331176505    4235.180000    4092.090000
# 24     217789755       0.219417       0.212449
# 25        642091       9.660000       9.580000
# 26     460950230     107.280000     105.460000
# 27    3048172415       1.003000       0.997408
# 28       7751613       1.001000       0.998066
# 29     470216018       1.001000       0.999591
# 30     346099538  114533.000000  111601.000000
# 31     162214337       0.000012       0.000012
# 32     112088747       2.730000       2.670000
# 33      50451993       0.197286       0.187600
# 34     357514165       1.950000       1.730000
# 35      44982526      42.220000      41.250000
# 36     251095391       4.020000       3.880000
# 37     122635871       1.200000       1.200000
# 38     443064107       0.221742       0.201903
# 39     105405765     293.640000     285.660000
# 40     226275096       7.830000       7.590000
# 41     157414048       1.001000       0.997448
# 42     390692831     280.180000     269.560000
# 43      69503523     193.700000     188.860000
# 44     395893400       0.000009       0.000009
# 45     300176660       0.601874       0.557938
# 46     289867201       5.320000       5.170000
# 47     214906871       2.830000       2.700000
# 48      21356379     264.470000     253.040000
# 49     970811635       1.990000       1.790000
#
#     price_change_percentage_1h_in_currency  \
# 0                                 0.134874
# 1                                 0.057965
# 2                                 0.002564
# 3                                -0.167751
# 4                                -0.110228
# 5                                -0.167424
# 6                                -0.005077
# 7                                 0.086559
# 8                                -0.409986
# 9                                 0.121914
# 10                               -0.258287
# 11                                0.078305
# 12                                0.078779
# 13                               -0.096383
# 14                                0.107914
# 15                                0.002677
# 16                                0.000000
# 17                               -0.522187
# 18                               -0.713818
# 19                               -0.127316
# 20                               -0.347000
# 21                                0.070471
# 22                                0.035614
# 23                                0.047622
# 24                               -0.446797
# 25                                0.032159
# 26                               -0.087231
# 27                                0.034332
# 28                               -0.014926
# 29                                0.020826
# 30                                0.118673
# 31                               -0.022259
# 32                               -0.347268
# 33                               -0.438901
# 34                               -1.060588
# 35                                0.052327
# 36                               -0.266781
# 37                                0.017987
# 38                               -0.965958
# 39                               -0.321248
# 40                               -0.339888
# 41                                0.012234
# 42                               -0.219904
# 43                                0.251102
# 44                               -0.311034
# 45                               -0.869275
# 46                                0.402138
# 47                               -0.450065
# 48                               -0.122475
# 49                               -0.237609
#
#     price_change_percentage_24h_in_currency  \
# 0                                  2.012834
# 1                                  2.412481
# 2                                  0.022374
# 3                                  0.846490
# 4                                  4.458525
# 5                                  1.551824
# 6                                 -0.003960
# 7                                  2.399561
# 8                                 -0.323179
# 9                                  0.529023
# 10                                -0.063414
# 11                                 2.388715
# 12                                 2.325248
# 13                                 0.656397
# 14                                 2.021543
# 15                                 0.024458
# 16                                 6.708934
# 17                                 1.789123
# 18                                -1.501712
# 19                                 1.105545
# 20                                 0.130022
# 21                                 0.815947
# 22                                 2.382113
# 23                                 2.385795
# 24                                 0.376904
# 25                                 0.472054
# 26                                -0.099149
# 27                                 0.021287
# 28                                -0.038797
# 29                                 0.032020
# 30                                 1.932537
# 31                                -0.149692
# 32                                -0.739264
# 33                                -1.650655
# 34                                 7.292914
# 35                                 1.356300
# 36                                -0.214066
# 37                                 0.006377
# 38                                -8.585064
# 39                                -0.421143
# 40                                 0.054950
# 41                                 0.130137
# 42                                 1.018514
# 43                                -0.689188
# 44                                -0.075523
# 45                                -5.954104
# 46                                 2.684949
# 47                                -0.618339
# 48                                 1.463062
# 49                                -0.560780
#
#     price_change_percentage_7d_in_currency                     last_updated  \
# 0                                 1.198553 2025-09-29 23:20:22.786000+00:00
# 1                                 0.723453 2025-09-29 23:20:25.315000+00:00
# 2                                -0.016332 2025-09-29 23:20:21.246000+00:00
# 3                                 1.195363 2025-09-29 23:20:19.767000+00:00
# 4                                 4.140284 2025-09-29 23:20:22.739000+00:00
# 5                                -3.401862 2025-09-29 23:20:20.136000+00:00
# 6                                -0.010608 2025-09-29 23:20:21.750000+00:00
# 7                                 0.828639 2025-09-29 23:20:25.078000+00:00
# 8                                -1.866603 2025-09-29 23:20:25.365000+00:00
# 9                                -0.662565 2025-09-29 23:20:21.046000+00:00
# 10                               -2.277889 2025-09-29 23:20:24.545000+00:00
# 11                                0.870630 2025-09-29 23:20:21.857000+00:00
# 12                                0.831956 2025-09-29 23:20:21.645000+00:00
# 13                                1.001781 2025-09-29 23:20:24.643000+00:00
# 14                                1.283961 2025-09-29 23:20:22.172000+00:00
# 15                               -0.027246 2025-09-29 23:20:25.534000+00:00
# 16                                4.932157 2025-09-29 23:20:25.410000+00:00
# 17                               -7.803604 2025-09-29 23:20:23.332000+00:00
# 18                               -3.623608 2025-09-29 23:20:15.778000+00:00
# 19                                1.288696 2025-09-29 23:20:20.405000+00:00
# 20                               -2.399946 2025-09-29 23:20:20.814000+00:00
# 21                               -0.649718 2025-09-29 23:20:23.770000+00:00
# 22                                0.817259 2025-09-29 23:20:21.785000+00:00
# 23                                0.833545 2025-09-29 23:20:22.308000+00:00
# 24                               -2.036027 2025-09-29 23:20:26.358000+00:00
# 25                                1.634064 2025-09-29 23:20:16.347000+00:00
# 26                                0.631964 2025-09-29 23:20:16.833000+00:00
# 27                               -0.013630 2025-09-29 23:20:23.911000+00:00
# 28                               -0.004225 2025-09-29 23:20:21.056000+00:00
# 29                                0.010147 2025-09-29 23:20:21.885000+00:00
# 30                                1.109282 2025-09-29 23:20:24.712000+00:00
# 31                               -0.882936 2025-09-29 23:20:19.780000+00:00
# 32                               -3.788779 2025-09-29 23:20:21.017000+00:00
# 33                               -9.188599 2025-09-29 23:20:24.753000+00:00
# 34                               11.150900 2025-09-29 23:20:16.845000+00:00
# 35                               -0.438197 2025-09-29 23:20:21.467000+00:00
# 36                               -1.090853 2025-09-29 23:20:18.796000+00:00
# 37                                0.147169 2025-09-29 23:20:25.288000+00:00
# 38                               -4.621732 2025-09-29 23:20:21.861000+00:00
# 39                                0.096589 2025-09-29 23:20:17.296000+00:00
# 40                               -5.464821 2025-09-29 23:20:21.361000+00:00
# 41                                0.030215 2025-09-29 23:20:24.979000+00:00
# 42                                3.360283 2025-09-29 23:20:22.523000+00:00
# 43                                4.059997 2025-09-29 23:20:17.836000+00:00
# 44                               -2.390572 2025-09-29 23:20:18.436000+00:00
# 45                               -5.693727 2025-09-29 23:20:25.548000+00:00
# 46                                3.314060 2025-09-29 23:20:23.435000+00:00
# 47                               -6.464676 2025-09-29 23:20:17.604000+00:00
# 48                               -3.081355 2025-09-29 23:20:16.017000+00:00
# 49                               17.463891 2025-09-29 23:20:23.019000+00:00
#
#                          run_ts_utc
# 0  2025-09-29 23:24:10.401645+00:00
# 1  2025-09-29 23:24:10.401645+00:00
# 2  2025-09-29 23:24:10.401645+00:00
# 3  2025-09-29 23:24:10.401645+00:00
# 4  2025-09-29 23:24:10.401645+00:00
# 5  2025-09-29 23:24:10.401645+00:00
# 6  2025-09-29 23:24:10.401645+00:00
# 7  2025-09-29 23:24:10.401645+00:00
# 8  2025-09-29 23:24:10.401645+00:00
# 9  2025-09-29 23:24:10.401645+00:00
# 10 2025-09-29 23:24:10.401645+00:00
# 11 2025-09-29 23:24:10.401645+00:00
# 12 2025-09-29 23:24:10.401645+00:00
# 13 2025-09-29 23:24:10.401645+00:00
# 14 2025-09-29 23:24:10.401645+00:00
# 15 2025-09-29 23:24:10.401645+00:00
# 16 2025-09-29 23:24:10.401645+00:00
# 17 2025-09-29 23:24:10.401645+00:00
# 18 2025-09-29 23:24:10.401645+00:00
# 19 2025-09-29 23:24:10.401645+00:00
# 20 2025-09-29 23:24:10.401645+00:00
# 21 2025-09-29 23:24:10.401645+00:00
# 22 2025-09-29 23:24:10.401645+00:00
# 23 2025-09-29 23:24:10.401645+00:00
# 24 2025-09-29 23:24:10.401645+00:00
# 25 2025-09-29 23:24:10.401645+00:00
# 26 2025-09-29 23:24:10.401645+00:00
# 27 2025-09-29 23:24:10.401645+00:00
# 28 2025-09-29 23:24:10.401645+00:00
# 29 2025-09-29 23:24:10.401645+00:00
# 30 2025-09-29 23:24:10.401645+00:00
# 31 2025-09-29 23:24:10.401645+00:00
# 32 2025-09-29 23:24:10.401645+00:00
# 33 2025-09-29 23:24:10.401645+00:00
# 34 2025-09-29 23:24:10.401645+00:00
# 35 2025-09-29 23:24:10.401645+00:00
# 36 2025-09-29 23:24:10.401645+00:00
# 37 2025-09-29 23:24:10.401645+00:00
# 38 2025-09-29 23:24:10.401645+00:00
# 39 2025-09-29 23:24:10.401645+00:00
# 40 2025-09-29 23:24:10.401645+00:00
# 41 2025-09-29 23:24:10.401645+00:00
# 42 2025-09-29 23:24:10.401645+00:00
# 43 2025-09-29 23:24:10.401645+00:00
# 44 2025-09-29 23:24:10.401645+00:00
# 45 2025-09-29 23:24:10.401645+00:00
# 46 2025-09-29 23:24:10.401645+00:00
# 47 2025-09-29 23:24:10.401645+00:00
# 48 2025-09-29 23:24:10.401645+00:00
# 49 2025-09-29 23:24:10.401645+00:00

# %% [markdown]
# ## Load
#
#    - Guardado local en **Parquet** (en carpeta `./data/`).
#    - Subida a **Amazon S3** con `boto3` (reemplaza por tu bucket, región y credenciales).

# %% [markdown]
# ### PARQUET

# %%
os.makedirs("data", exist_ok=True)

run_dt = datetime.now(timezone.utc)
date_part = run_dt.strftime("%Y/%m/%d")
ts_part = run_dt.strftime("%Y%m%dT%H%M%SZ")

local_dir = Path("data") / "crypto_markets" / f"dt={date_part}"
local_dir.mkdir(parents=True, exist_ok=True)
local_path = local_dir / f"coingecko_top50_{ts_part}.parquet"

df.to_parquet(local_path, index=False)
local_path
# Out:
# PosixPath('data/crypto_markets/dt=2025/09/29/coingecko_top50_20250929T232554Z.parquet')

# %% [markdown]
# ### S3

# %%
AWS_REGION = os.getenv("AWS_REGION", "us-east-1")
S3_BUCKET = os.getenv("S3_BUCKET", "coingecko-prefect")
S3_PREFIX = os.getenv("S3_PREFIX", "etl/crypto_markets")

def upload_file_to_s3(local_path: str, bucket: str, key: str, region: str | None = None) -> str:
    session_kwargs = {}
    if region:
        session_kwargs["region_name"] = region
    session = boto3.Session(**session_kwargs)
    s3 = session.client("s3")
    s3.upload_file(Filename=str(local_path), Bucket=bucket, Key=key)
    return f"s3://{bucket}/{key}"

s3_key = f"{S3_PREFIX}/dt={date_part}/coingecko_top50_{ts_part}.parquet"
try:
    s3_uri = upload_file_to_s3(local_path, S3_BUCKET, s3_key, AWS_REGION)
    print("Subido a:", s3_uri)
except ClientError as e:
    print("Error al subir a S3:", e)
# Out:
# Subido a: s3://coingecko-prefect/etl/crypto_markets/dt=2025/09/29/coingecko_top50_20250929T232554Z.parquet
